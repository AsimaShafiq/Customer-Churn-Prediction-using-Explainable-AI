# %% [markdown]
# # Customer Churn Prediction Application using Streamlit

# %% [markdown]
# ## Project Overview
#
# This phase focuses on developing an interactive Streamlit application for the trained customer churn prediction model. Users will enter customer information through a simple interface, and the application will generate a churn prediction and probability using the saved preprocessor and trained model.

# %% [markdown]
# ## Objectives
#
# - Build an interactive application using Streamlit.
# - Collect customer information through user input fields.
# - Apply the saved preprocessing component.
# - Generate churn predictions and probabilities.
# - Present results in a clear and user-friendly format.

# %% [markdown]
# ## Installing Streamlit
#
# Streamlit is used to create an interactive web interface for the customer churn prediction system.

# %%
# !pip install streamlit
# Out:
# Requirement already satisfied: streamlit in /usr/local/lib/python3.12/dist-packages (1.61.1)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<7,>=5.0.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (1.9.0)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (8.4.2)
# Requirement already satisfied: numpy<3,>=1.23 in /usr/local/lib/python3.12/dist-packages (from streamlit) (2.0.2)
# Requirement already satisfied: packaging>=20 in /usr/local/lib/python3.12/dist-packages (from streamlit) (26.2)
# Requirement already satisfied: pandas<4,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (2.2.2)
# Requirement already satisfied: pillow<13,>=7.1.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (11.3.0)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /usr/local/lib/python3.12/dist-packages (from streamlit) (0.9.3)
# Requirement already satisfied: protobuf<8,>=5.26.1 in /usr/local/lib/python3.12/dist-packages (from streamlit) (5.29.6)
# Requirement already satisfied: pyarrow<25,>=7.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (18.1.0)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.12/dist-packages (from streamlit) (2.32.4)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (9.1.4)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.12/dist-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (4.16.0)
# Requirement already satisfied: starlette<1.4.0,>=0.46.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (1.3.1)
# Requirement already satisfied: uvicorn<1,>=0.30.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (0.51.0)
# Requirement already satisfied: httptools<1,>=0.6.3 in /usr/local/lib/python3.12/dist-packages (from streamlit) (0.8.0)
# Requirement already satisfied: anyio<5,>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (4.14.2)
# Requirement already satisfied: python-multipart<1,>=0.0.10 in /usr/local/lib/python3.12/dist-packages (from streamlit) (0.0.32)
# Requirement already satisfied: websockets<17,>=12.0.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (15.0.1)
# Requirement already satisfied: itsdangerous<3,>=2.1.2 in /usr/local/lib/python3.12/dist-packages (from streamlit) (2.2.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in /usr/local/lib/python3.12/dist-packages (from streamlit) (6.0.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from altair!=5.4.0,!=5.4.1,<7,>=5.0.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.12/dist-packages (from altair!=5.4.0,!=5.4.1,<7,>=5.0.0->streamlit) (4.26.0)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.12/dist-packages (from altair!=5.4.0,!=5.4.1,<7,>=5.0.0->streamlit) (2.24.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=4.0.0->streamlit) (3.18)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<4,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<4,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<4,>=1.4.0->streamlit) (2026.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->streamlit) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->streamlit) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->streamlit) (2026.6.17)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.12/dist-packages (from uvicorn<1,>=0.30.0->streamlit) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->altair!=5.4.0,!=5.4.1,<7,>=5.0.0->streamlit) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=5.0.0->streamlit) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=5.0.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=5.0.0->streamlit) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=5.0.0->streamlit) (2026.6.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas<4,>=1.4.0->streamlit) (1.17.0)

# %% [markdown]
# ## Importing Required Libraries:

# %%
import streamlit as st
import pandas as pd
import joblib

# %% [markdown]
# ## Loading Saved Components
#
# The saved preprocessor and trained model will be loaded to process new customer data and generate predictions.

# %%
# Load the saved preprocessor and model
preprocessor = joblib.load('/content/Preprocessor.pkl')
model = joblib.load('/content/Model.pkl')

# %% [markdown]
# ## Creating the Application Interface
#
# A simple interface is created to introduce the application and guide users to enter customer information.

# %%
st.title("Customer Churn Prediction")
st.write("Enter customer information to predict the likelihood of churn.")
# Out:
# 2026-08-12 06:53:43.264 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.394
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /usr/local/lib/python3.12/dist-packages/colab_kernel_launcher.py [ARGUMENTS]
# 2026-08-12 06:53:43.395 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.395 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.397 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.398 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.399 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %% [markdown]
# ## Collecting Personal Information
#
# Basic customer information is collected through interactive input fields.

# %%
st.subheader("Personal Information")

gender = st.selectbox(
    "Gender",
    ["Female", "Male"]
)

senior_citizen = st.selectbox(
    "Senior Citizen",
    ["No", "Yes"]
)

partner = st.selectbox(
    "Partner",
    ["No", "Yes"]
)

dependents = st.selectbox(
    "Dependents",
    ["No", "Yes"]
)
# Out:
# 2026-08-12 06:53:43.404 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.406 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.406 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.407 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.409 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.410 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.410 Session state does not function when running a script without `streamlit run`
# 2026-08-12 06:53:43.411 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.412 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.412 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.413 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.415 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.416 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.416 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.417 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.418 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.419 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.421 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.421 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.422 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.423 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.424 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.424 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.425 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.426 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.427 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.427 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.428 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %% [markdown]
# ## Collecting Service Information
#
# Service-related customer information is collected to provide the features required for churn prediction.

# %%
st.subheader("Service Information")

phone_service = st.selectbox(
    "Phone Service",
    ["No", "Yes"]
)

multiple_lines = st.selectbox(
    "Multiple Lines",
    ["No", "Yes", "No phone service"]
)

internet_service = st.selectbox(
    "Internet Service",
    ["DSL", "Fiber optic", "No"]
)
# Out:
# 2026-08-12 06:53:43.436 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.436 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.437 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.438 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.439 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.439 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.441 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.442 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.443 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.443 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.444 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.445 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.446 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.446 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.447 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.448 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.449 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.449 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.450 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.451 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.451 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
online_security = st.selectbox(
    "Online Security",
    ["No", "Yes", "No internet service"]
)

online_backup = st.selectbox(
    "Online Backup",
    ["No", "Yes", "No internet service"]
)

device_protection = st.selectbox(
    "Device Protection",
    ["No", "Yes", "No internet service"]
)

tech_support = st.selectbox(
    "Tech Support",
    ["No", "Yes", "No internet service"]
)

streaming_tv = st.selectbox(
    "Streaming TV",
    ["No", "Yes", "No internet service"]
)

streaming_movies = st.selectbox(
    "Streaming Movies",
    ["No", "Yes", "No internet service"]
)
# Out:
# 2026-08-12 06:53:43.459 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.460 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.460 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.461 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.462 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.463 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.463 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.464 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.465 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.465 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.466 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.467 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.468 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.469 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.470 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.470 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.471 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.473 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.473 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.474 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.474 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.475 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.476 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.477 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.478 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.478 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.479 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.479 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.481 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.481 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.482 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.483 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.483 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.484 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.485 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.486 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %% [markdown]
# ## Collecting Contract and Payment Information
#
# Contract and payment information is collected as part of the features used by the churn prediction model.

# %%
st.subheader("Contract and Payment Information")

contract = st.selectbox(
    "Contract",
    ["Month-to-month", "One year", "Two year"]
)

paperless_billing = st.selectbox(
    "Paperless Billing",
    ["No", "Yes"]
)

payment_method = st.selectbox(
    "Payment Method",
    [
        "Bank transfer (automatic)",
        "Credit card (automatic)",
        "Electronic check",
        "Mailed check"
    ]
)
# Out:
# 2026-08-12 06:53:43.492 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.493 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.493 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.494 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.495 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.496 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.497 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.497 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.499 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.499 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.501 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.501 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.503 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.504 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.505 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.506 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.507 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.508 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.509 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.509 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.510 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %% [markdown]
# ## Collecting Numerical Information
#
# Numerical customer features are collected to complete the information required for churn prediction.

# %%
st.subheader("Numerical Information")

tenure_months = st.number_input(
    "Tenure Months",
    min_value=0,
    step=1
)

monthly_charges = st.number_input(
    "Monthly Charges",
    min_value=0.0,
    step=0.01
)

total_charges = st.number_input(
    "Total Charges",
    min_value=0.0,
    step=0.01
)

cltv = st.number_input(
    "CLTV",
    min_value=0.0,
    step=1.0
)
# Out:
# 2026-08-12 06:53:43.519 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.520 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.521 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.522 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.523 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.524 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.524 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.525 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.526 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.527 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.527 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.529 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.529 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.530 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.530 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.531 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.532 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.532 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.535 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.536 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.536 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.537 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.537 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.539 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.540 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.540 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-12 06:53:43.541 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %% [markdown]
# ## Creating Engineered Features
#
# Some features used by the trained model were created during feature engineering. These features are automatically generated from the customer information entered by the user to ensure consistency with the model's training data.

# %% [markdown]
# ### Service-Based Features
#
# Service-related engineered features are calculated by counting or combining the services selected by the customer.

# %%
additional_services = [
    online_security,
    online_backup,
    device_protection,
    tech_support
]

total_additional_services = sum(
    service == "Yes"
    for service in additional_services
)


streaming_services = [
    streaming_tv,
    streaming_movies
]

total_streaming_services = sum(
    service == "Yes"
    for service in streaming_services
)

# %% [markdown]
# ### Tenure Group
#
# Customer tenure is grouped into categories using the same ranges applied during feature engineering.

# %%
if tenure_months <= 12:
    tenure_group = "New"

elif tenure_months <= 24:
    tenure_group = "Early"

elif tenure_months <= 48:
    tenure_group = "Established"

else:
    tenure_group = "Long-term"

# %% [markdown]
# ### Has Multiple Services
#
# This feature identifies whether a customer has two or more additional services. A value of `1` indicates that the customer has multiple services, while `0` indicates fewer than two additional services.

# %%
has_multiple_services = int(
    total_additional_services >= 2
)

# %% [markdown]
# ### Total Security Services
#
# This feature represents the number of security-related services selected by the customer. It is calculated by counting the services with a value of `Yes`.

# %%
security_services = [
    online_security,
    online_backup,
    device_protection
]

total_security_services = sum(
    service == "Yes"
    for service in security_services
)

# %% [markdown]
# ## Creating Customer Input Data
#
# The customer information and engineered features are combined into a single DataFrame. The feature names and structure must match the input expected by the saved preprocessor.

# %%
customer_data = pd.DataFrame({

    "Tenure Months": [tenure_months],
    "Monthly Charges": [monthly_charges],
    "Total Charges": [total_charges],
    "CLTV": [cltv],

    "Total Aditional Services": [total_additional_services],
    "Total Streaming Services": [total_streaming_services],
    "Total Security Services": [total_security_services],
    "Has Multiple Services": [has_multiple_services],

    "Gender": [gender],
    "Senior Citizen": [senior_citizen],
    "Partner": [partner],
    "Dependents": [dependents],

    "Phone Service": [phone_service],
    "Multiple Lines": [multiple_lines],
    "Internet Service": [internet_service],

    "Online Security": [online_security],
    "Online Backup": [online_backup],
    "Device Protection": [device_protection],
    "Tech Support": [tech_support],

    "Streaming TV": [streaming_tv],
    "Streaming Movies": [streaming_movies],

    "Contract": [contract],
    "Paperless Billing": [paperless_billing],
    "Payment Method": [payment_method],

    "Tenure Group": [tenure_group]
})

# %% [markdown]
# ## Verifying Customer Data
#
# The customer DataFrame is checked to confirm that it contains the required features before applying the saved preprocessor.

# %%
print(customer_data)
print(customer_data.shape)
# Out:
#    Tenure Months  Monthly Charges  Total Charges  CLTV  \
# 0              0              0.0            0.0   0.0
#
#    Total Aditional Services  Total Streaming Services  \
# 0                         0                         0
#
#    Total Security Services  Has Multiple Services  Gender Senior Citizen  ...  \
# 0                        0                      0  Female             No  ...
#
#   Online Security Online Backup Device Protection Tech Support Streaming TV  \
# 0              No            No                No           No           No
#
#   Streaming Movies        Contract Paperless Billing  \
# 0               No  Month-to-month                No
#
#               Payment Method Tenure Group
# 0  Bank transfer (automatic)          New
#
# [1 rows x 25 columns]

# %% [markdown]
# ## Verifying Input Features
#
# The customer input features are compared with the features expected by the saved preprocessor to ensure consistency before generating a prediction.

# %%
print("Customer Data Columns:")
print(list(customer_data.columns))

print("\nPreprocessor Expected Columns:")
print(list(preprocessor.feature_names_in_))
# Out:
# Customer Data Columns:
# ['Tenure Months', 'Monthly Charges', 'Total Charges', 'CLTV', 'Total Aditional Services', 'Total Streaming Services', 'Total Security Services', 'Has Multiple Services', 'Gender', 'Senior Citizen', 'Partner', 'Dependents', 'Phone Service', 'Multiple Lines', 'Internet Service', 'Online Security', 'Online Backup', 'Device Protection', 'Tech Support', 'Streaming TV', 'Streaming Movies', 'Contract', 'Paperless Billing', 'Payment Method', 'Tenure Group']
#
# Preprocessor Expected Columns:
# ['Gender', 'Senior Citizen', 'Partner', 'Dependents', 'Tenure Months', 'Phone Service', 'Multiple Lines', 'Internet Service', 'Online Security', 'Online Backup', 'Device Protection', 'Tech Support', 'Streaming TV', 'Streaming Movies', 'Contract', 'Paperless Billing', 'Payment Method', 'Monthly Charges', 'Total Charges', 'CLTV', 'Total Aditional Services', 'Total Streaming Services', 'Total Security Services', 'Tenure Group', 'Has Multiple Services']

# %% [markdown]
# ### Aligning Feature Order
#
# The customer data columns are reordered to match the exact feature order expected by the saved preprocessor.

# %%
customer_data = customer_data[
    preprocessor.feature_names_in_
]

# %%
list(customer_data.columns) == list(preprocessor.feature_names_in_)
# Out:
# True

# %% [markdown]
# ## Preprocessing Customer Data
#
# The customer data is transformed using the saved preprocessor. This applies the same preprocessing steps used during model training.

# %%
customer_processed = preprocessor.transform(customer_data)

# %%
print(customer_processed.shape)
# Out:
# (1, 55)

# %% [markdown]
# ## Generating the Churn Prediction
#
# The processed customer data is passed to the trained model to predict whether the customer is likely to churn.

# %%
prediction = model.predict(customer_processed)[0]
print(prediction)
# Out:
# 1

# %% [markdown]
# ## Calculating Churn Probability
#
# The trained model is used to calculate the probability that the customer belongs to the churn class.

# %%
probability = model.predict_proba(customer_processed)[0, 1]
print(f"Churn Probability: {probability:.2%}")
# Out:
# Churn Probability: 52.11%

# %% [markdown]
# ## Creating a User-Friendly Prediction
#
# The numerical prediction is converted into a clear result that can be easily understood by the user.

# %%
if prediction == 1:
    result = "Likely to Churn"
else:
    result = "Likely to Stay"

print("Prediction:", result)
print(f"Churn Probability: {probability:.2%}")
# Out:
# Prediction: Likely to Churn
# Churn Probability: 52.11%

# %% [markdown]
# ## Testing the Complete Prediction Workflow
#
# The complete workflow is tested to confirm that customer information can be transformed, processed, and successfully used to generate a churn prediction and probability.

# %% [markdown]
# ## Creating a Reusable Prediction Function
#
# A reusable function is created to combine preprocessing, prediction, and probability calculation into a single process.

# %%
def predict_churn(customer_data):

    processed_data = preprocessor.transform(customer_data)

    prediction = model.predict(processed_data)[0]

    probability = model.predict_proba(processed_data)[0, 1]

    if prediction == 1:
        result = "Likely to Churn"
    else:
        result = "Likely to Stay"

    return result, probability

# %% [markdown]
# ## Testing the Prediction Function
#
# The reusable prediction function is tested using the prepared customer data to verify that it successfully generates a prediction and churn probability.

# %%
result, probability = predict_churn(customer_data)

print("Prediction:", result)
print(f"Churn Probability: {probability:.2%}")
# Out:
# Prediction: Likely to Churn
# Churn Probability: 52.11%

# %% [markdown]
# ## Creating the Streamlit Application
#
# After testing the complete prediction workflow, the application logic is combined into a single Python file named `app.py` for deployment using Streamlit.

# %%
# %%writefile app.py

import streamlit as st
import pandas as pd
import joblib


# --------------------------------------------------
# Page Configuration
# --------------------------------------------------

st.set_page_config(
    page_title="Customer Churn Prediction",
    page_icon="📊",
    layout="wide"
)


# --------------------------------------------------
# Load Saved Components
# --------------------------------------------------

preprocessor = joblib.load("Preprocessor.pkl")
model = joblib.load("Model.pkl")


# --------------------------------------------------
# Sidebar
# --------------------------------------------------

with st.sidebar:
    st.header("About the Project")

    st.write(
        """
        This application predicts whether a customer
        is likely to churn based on customer,
        service, contract, and billing information.
        """
    )

    st.markdown("---")

    st.caption(
        "Machine Learning Customer Churn Prediction System"
    )


# --------------------------------------------------
# Application Header
# --------------------------------------------------

st.title("📊 Customer Churn Prediction")

st.write(
    "Enter customer information below to predict the likelihood of churn."
)

st.markdown("---")


# --------------------------------------------------
# Customer Input Form
# --------------------------------------------------

with st.form("customer_form"):

    # Personal Information
    st.subheader("👤 Personal Information")

    col1, col2, col3, col4 = st.columns(4)

    with col1:
        gender = st.selectbox(
            "Gender",
            ["Female", "Male"]
        )

    with col2:
        senior_citizen = st.selectbox(
            "Senior Citizen",
            ["No", "Yes"]
        )

    with col3:
        partner = st.selectbox(
            "Partner",
            ["No", "Yes"]
        )

    with col4:
        dependents = st.selectbox(
            "Dependents",
            ["No", "Yes"]
        )


    # --------------------------------------------------
    # Service Information
    # --------------------------------------------------

    st.subheader("📡 Service Information")

    col1, col2, col3 = st.columns(3)

    with col1:
        phone_service = st.selectbox(
            "Phone Service",
            ["No", "Yes"]
        )

    with col2:
        multiple_lines = st.selectbox(
            "Multiple Lines",
            ["No", "Yes", "No phone service"]
        )

    with col3:
        internet_service = st.selectbox(
            "Internet Service",
            ["DSL", "Fiber optic", "No"]
        )


    col1, col2, col3 = st.columns(3)

    with col1:
        online_security = st.selectbox(
            "Online Security",
            ["No", "Yes", "No internet service"]
        )

        device_protection = st.selectbox(
            "Device Protection",
            ["No", "Yes", "No internet service"]
        )

    with col2:
        online_backup = st.selectbox(
            "Online Backup",
            ["No", "Yes", "No internet service"]
        )

        tech_support = st.selectbox(
            "Tech Support",
            ["No", "Yes", "No internet service"]
        )

    with col3:
        streaming_tv = st.selectbox(
            "Streaming TV",
            ["No", "Yes", "No internet service"]
        )

        streaming_movies = st.selectbox(
            "Streaming Movies",
            ["No", "Yes", "No internet service"]
        )


    # --------------------------------------------------
    # Contract and Payment Information
    # --------------------------------------------------

    st.subheader("📄 Contract and Payment Information")

    col1, col2, col3 = st.columns(3)

    with col1:
        contract = st.selectbox(
            "Contract",
            ["Month-to-month", "One year", "Two year"]
        )

    with col2:
        paperless_billing = st.selectbox(
            "Paperless Billing",
            ["No", "Yes"]
        )

    with col3:
        payment_method = st.selectbox(
            "Payment Method",
            [
                "Bank transfer (automatic)",
                "Credit card (automatic)",
                "Electronic check",
                "Mailed check"
            ]
        )


    # --------------------------------------------------
    # Numerical Information
    # --------------------------------------------------

    st.subheader("💰 Customer Information")

    col1, col2 = st.columns(2)

    with col1:

        tenure_months = st.number_input(
            "Tenure Months",
            min_value=0,
            step=1
        )

        monthly_charges = st.number_input(
            "Monthly Charges",
            min_value=0.0,
            step=0.01
        )

    with col2:

        total_charges = st.number_input(
            "Total Charges",
            min_value=0.0,
            step=0.01
        )

        cltv = st.number_input(
            "CLTV",
            min_value=0.0,
            step=1.0
        )


    # --------------------------------------------------
    # Submit Button
    # --------------------------------------------------

    submitted = st.form_submit_button(
        "Predict Churn"
    )


# ==================================================
# Prediction Process
# ==================================================

if submitted:

    # --------------------------------------------------
    # Feature Engineering
    # --------------------------------------------------

    additional_services = [
        online_security,
        online_backup,
        device_protection,
        tech_support
    ]

    total_additional_services = sum(
        service == "Yes"
        for service in additional_services
    )


    streaming_services = [
        streaming_tv,
        streaming_movies
    ]

    total_streaming_services = sum(
        service == "Yes"
        for service in streaming_services
    )


    security_services = [
        online_security,
        online_backup,
        device_protection
    ]

    total_security_services = sum(
        service == "Yes"
        for service in security_services
    )


    has_multiple_services = int(
        total_additional_services >= 2
    )


    # --------------------------------------------------
    # Tenure Group
    # --------------------------------------------------

    if tenure_months <= 12:
        tenure_group = "New"

    elif tenure_months <= 24:
        tenure_group = "Early"

    elif tenure_months <= 48:
        tenure_group = "Established"

    else:
        tenure_group = "Long-term"


    # --------------------------------------------------
    # Create Customer Data
    # --------------------------------------------------

    customer_data = pd.DataFrame({

        "Tenure Months": [tenure_months],
        "Monthly Charges": [monthly_charges],
        "Total Charges": [total_charges],
        "CLTV": [cltv],

        "Total Aditional Services": [
            total_additional_services
        ],

        "Total Streaming Services": [
            total_streaming_services
        ],

        "Total Security Services": [
            total_security_services
        ],

        "Has Multiple Services": [
            has_multiple_services
        ],

        "Gender": [gender],
        "Senior Citizen": [senior_citizen],
        "Partner": [partner],
        "Dependents": [dependents],

        "Phone Service": [phone_service],
        "Multiple Lines": [multiple_lines],
        "Internet Service": [internet_service],

        "Online Security": [online_security],
        "Online Backup": [online_backup],
        "Device Protection": [device_protection],
        "Tech Support": [tech_support],

        "Streaming TV": [streaming_tv],
        "Streaming Movies": [streaming_movies],

        "Contract": [contract],
        "Paperless Billing": [paperless_billing],
        "Payment Method": [payment_method],

        "Tenure Group": [tenure_group]

    })


    # --------------------------------------------------
    # Align Feature Order
    # --------------------------------------------------

    customer_data = customer_data[
        preprocessor.feature_names_in_
    ]


    # --------------------------------------------------
    # Preprocessing
    # --------------------------------------------------

    processed_data = preprocessor.transform(
        customer_data
    )


    # --------------------------------------------------
    # Prediction
    # --------------------------------------------------

    prediction = model.predict(
        processed_data
    )[0]


    probability = model.predict_proba(
        processed_data
    )[0, 1]


    # --------------------------------------------------
    # Display Results
    # --------------------------------------------------

    st.markdown("---")

    st.subheader("Prediction Result")

    result_col1, result_col2 = st.columns(2)

    with result_col1:

        if prediction == 1:

            st.error(
                "⚠️ Likely to Churn"
            )

        else:

            st.success(
                "✅ Likely to Stay"
            )


    with result_col2:

        st.metric(
            "Churn Probability",
            f"{probability:.2%}"
        )


    # --------------------------------------------------
    # Risk Interpretation
    # --------------------------------------------------

    if probability >= 0.70:

        st.warning(
            "High churn risk detected."
        )

    elif probability >= 0.40:

        st.info(
            "Moderate churn risk detected."
        )

    else:

        st.success(
            "Low churn risk detected."
        )
# Out:
# Writing app.py

# %% [markdown]
# ## Verifying the Application File
#
# The generated `app.py` file contains the complete Streamlit application, including user input, feature engineering, preprocessing, prediction, and result presentation.

# %%
# !ls
# Out:
# app.py	Model.pkl  Preprocessor.pkl  sample_data

# %% [markdown]
# ## Running the Streamlit Application
#
# The Streamlit application is launched using the generated `app.py` file. The application uses the saved preprocessor and trained model to generate churn predictions from customer input.

# %%
# !streamlit run app.py &>/content/logs.txt &

# %%
# !cat /content/logs.txt
# Out:
# Collecting usage statistics. To deactivate, set browser.gatherUsageStats to false.
#
# 2026-08-12 07:18:40.466 Uvicorn server started on :::8501
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.125.218.149:8501

# %%
# !wget -q https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64.deb
# !dpkg -i cloudflared-linux-amd64.deb
# Out:
# (Reading database ... 122496 files and directories currently installed.)
# Preparing to unpack cloudflared-linux-amd64.deb ...
# Unpacking cloudflared (2026.7.3) over (2026.7.3) ...
# Setting up cloudflared (2026.7.3) ...
# Processing triggers for man-db (2.10.2-1) ...

# %%
# !pkill -f streamlit

# %%
# !streamlit run app.py --server.port 8502 --server.address 0.0.0.0 > /content/logs.txt 2>&1 &

# %%
# !sleep 5 && cat /content/logs.txt
# Out:
# Collecting usage statistics. To deactivate, set browser.gatherUsageStats to false.
#
# 2026-08-12 07:18:57.739 Uvicorn server started on 0.0.0.0:8502
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8502
#   Network URL: http://172.28.0.12:8502
#   External URL: http://34.125.218.149:8502

# %%
# !cloudflared tunnel --url http://localhost:8502
# Out:
# 2026-08-12T07:19:09Z INF Thank you for trying Cloudflare Tunnel. Doing so, without a Cloudflare account, is a quick way to experiment and try it out. However, be aware that these account-less Tunnels have no uptime guarantee, are subject to the Cloudflare Online Services Terms of Use (https://www.cloudflare.com/website-terms/), and Cloudflare reserves the right to investigate your use of Tunnels for violations of such terms. If you intend to use Tunnels in production you should use a pre-created named tunnel by following: https://developers.cloudflare.com/cloudflare-one/connections/connect-apps
# 2026-08-12T07:19:09Z INF Requesting new quick Tunnel on trycloudflare.com...
# 2026-08-12T07:19:12Z INF +--------------------------------------------------------------------------------------------+
# 2026-08-12T07:19:12Z INF |  Your quick Tunnel has been created! Visit it at (it may take some time to be reachable):  |
# 2026-08-12T07:19:12Z INF |  https://provided-rachel-features-humor.trycloudflare.com                                  |
# 2026-08-12T07:19:12Z INF +--------------------------------------------------------------------------------------------+
# 2026-08-12T07:19:12Z INF Cannot determine default configuration path. No file [config.yml config.yaml] in [~/.cloudflared ~/.cloudflare-warp ~/cloudflare-warp /etc/cloudflared /usr/local/etc/cloudflared]
# 2026-08-12T07:19:12Z INF Version 2026.7.3 (Checksum 9d71c677db00134c1bd4144b7783486b654ad281b1ea62b4972098d19f770f17)
# 2026-08-12T07:19:12Z INF GOOS: linux, GOVersion: go1.26.4, GoArch: amd64
# 2026-08-12T07:19:12Z INF Settings: map[ha-connections:1 protocol:quic url:http://localhost:8502]
# 2026-08-12T07:19:12Z INF cloudflared will not automatically update if installed by a package manager.
# 2026-08-12T07:19:12Z INF Generated Connector ID: a5ba6fe9-2b0a-443d-a947-e27e990ecea8
# 2026-08-12T07:19:12Z INF Initial protocol quic
# 2026-08-12T07:19:12Z INF ICMP proxy will use 172.28.0.12 as source for IPv4
# 2026-08-12T07:19:12Z INF ICMP proxy will use ::1 in zone lo as source for IPv6
# 2026/08/12 07:19:12 failed to sufficiently increase receive buffer size (was: 208 kiB, wanted: 7168 kiB, got: 416 kiB). See https://github.com/quic-go/quic-go/wiki/UDP-Buffer-Sizes for details.
# 2026-08-12T07:19:12Z INF ICMP proxy will use 172.28.0.12 as source for IPv4
# 2026-08-12T07:19:12Z INF ICMP proxy will use ::1 in zone lo as source for IPv6
# 2026-08-12T07:19:12Z INF Starting metrics server on 127.0.0.1:20241/metrics
# 2026-08-12T07:19:12Z INF Tunnel connection curve preferences: [X25519MLKEM768 CurveID(65074) CurveP256] connIndex=0 event=0 ip=198.41.192.57
# 2026-08-12T07:19:13Z INF Registered tunnel connection connIndex=0 connection=b48cbccb-679d-4af9-9546-781ce348e38d event=0 ip=198.41.192.57 location=lax10 protocol=quic
# 2026-08-12T07:19:18Z INF +-------------------------------------------------------------------------------------+
# 2026-08-12T07:19:18Z INF |                               CONNECTIVITY PRE-CHECKS                               |
# 2026-08-12T07:19:18Z INF +-------------------------------------------------------------------------------------+
# 2026-08-12T07:19:18Z INF |  COMPONENT         TARGET                     STATUS  DETAILS                       |
# 2026-08-12T07:19:18Z INF |  DNS Resolution    region1.v2.argotunnel.com  PASS    DNS Resolved successfully     |
# 2026-08-12T07:19:18Z INF |  DNS Resolution    region2.v2.argotunnel.com  PASS    DNS Resolved successfully     |
# 2026-08-12T07:19:18Z INF |  UDP Connectivity  region1.v2.argotunnel.com  PASS    QUIC connection successful    |
# 2026-08-12T07:19:18Z INF |  UDP Connectivity  region2.v2.argotunnel.com  PASS    QUIC connection successful    |
# 2026-08-12T07:19:18Z INF |  TCP Connectivity  region1.v2.argotunnel.com  PASS    HTTP/2 connection successful  |
# 2026-08-12T07:19:18Z INF |  TCP Connectivity  region2.v2.argotunnel.com  PASS    HTTP/2 connection successful  |
# 2026-08-12T07:19:18Z INF |  Cloudflare API    api.cloudflare.com:443     PASS    API is reachable              |
# 2026-08-12T07:19:18Z INF |                                                                                     |
# 2026-08-12T07:19:18Z INF |  SUMMARY: Environment is healthy. cloudflared will use 'quic' as primary protocol.  |
# 2026-08-12T07:19:18Z INF +-------------------------------------------------------------------------------------+
# 2026-08-12T07:19:18Z INF precheck component="DNS Resolution" details="DNS Resolved successfully" run_id=4ed2668b-0571-49b1-8f3e-895a6f6d66de status=pass target=region1.v2.argotunnel.com
# 2026-08-12T07:19:18Z INF precheck component="DNS Resolution" details="DNS Resolved successfully" run_id=4ed2668b-0571-49b1-8f3e-895a6f6d66de status=pass target=region2.v2.argotunnel.com
# 2026-08-12T07:19:18Z INF precheck component="UDP Connectivity" details="QUIC connection successful" run_id=4ed2668b-0571-49b1-8f3e-895a6f6d66de status=pass target=region1.v2.argotunnel.com
# 2026-08-12T07:19:18Z INF precheck component="UDP Connectivity" details="QUIC connection successful" run_id=4ed2668b-0571-49b1-8f3e-895a6f6d66de status=pass target=region2.v2.argotunnel.com
# 2026-08-12T07:19:18Z INF precheck component="TCP Connectivity" details="HTTP/2 connection successful" run_id=4ed2668b-0571-49b1-8f3e-895a6f6d66de status=pass target=region1.v2.argotunnel.com
# 2026-08-12T07:19:18Z INF precheck component="TCP Connectivity" details="HTTP/2 connection successful" run_id=4ed2668b-0571-49b1-8f3e-895a6f6d66de status=pass target=region2.v2.argotunnel.com
# 2026-08-12T07:19:18Z INF precheck component="Cloudflare API" details="API is reachable" run_id=4ed2668b-0571-49b1-8f3e-895a6f6d66de status=pass target=api.cloudflare.com:443
# 2026-08-12T07:19:18Z INF precheck complete hard_fail=false run_id=4ed2668b-0571-49b1-8f3e-895a6f6d66de suggested_protocol=quic

# %% [markdown]
# ## Conclusion
#
# In this phase, the trained customer churn prediction model was transformed into an interactive Streamlit application.
#
# The application collects customer information, automatically generates the required engineered features, applies the saved preprocessing pipeline, and uses the trained machine learning model to generate a churn prediction and probability.
#
# The final application demonstrates the complete machine learning workflow, from user input and feature preparation to real-time prediction and result interpretation.
